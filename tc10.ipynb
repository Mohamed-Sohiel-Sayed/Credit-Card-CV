# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import utils as ut
import refFont

font = refFont.Font()

# %%
# Function to apply morphological operation
def apply_morphology(val):
    # Get trackbar positions
    kernel_size = cv2.getTrackbarPos('Kernel Size', 'Morphology')
    iterations = cv2.getTrackbarPos('Iterations', 'Morphology')

    # Ensure kernel size is odd and at least 1
    kernel_size = max(1, kernel_size * 2 + 1)
    
    # Create the kernel
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    
    morphed_image=img
    # global morphed_image
    # Apply the morphological operation
    for i in range(iterations):
        morphed_image = cv2.medianBlur(morphed_image, kernel_size)

    # Display the result
    cv2.imshow('Morphology', morphed_image)

# Load the image
img = cv2.imread('./TC/10.jpg', cv2.IMREAD_GRAYSCALE)
img=ut.resize_with_aspect_ratio(img, height=600)

# Create a window
cv2.namedWindow('Morphology')

# Create trackbars for operation type, kernel size, and iterations
cv2.createTrackbar('Kernel Size', 'Morphology', 1, 21, apply_morphology)
cv2.createTrackbar('Iterations', 'Morphology', 1, 10, apply_morphology)

# Initial update to display the image
apply_morphology(0)

# Wait until the user exits
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 5, in apply_morphology(val)
#       2 def apply_morphology(val):
#       3     # Get trackbar positions
#       4     kernel_size = cv2.getTrackbarPos('Kernel Size', 'Morphology')
# ----> 5     iterations = cv2.getTrackbarPos('Iterations', 'Morphology')
#       7     # Ensure kernel size is odd and at least 1
#       8     kernel_size = max(1, kernel_size * 2 + 1)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:866: error: (-215:Assertion failed) trackbar in function 'cv::getTrackbarPos'

# %%
# Function to apply morphological operation
def apply_morphology(val):
    # Get trackbar positions
    kernel_size = cv2.getTrackbarPos('Kernel Size', 'Morphology')
    iterations = cv2.getTrackbarPos('Iterations', 'Morphology')

    # Ensure kernel size is odd and at least 1
    kernel_size = max(1, kernel_size * 2 + 1)
    
    # Create the kernel
    kernel = np.ones((kernel_size, kernel_size), np.uint8)
    
    morphed_image=otsuThresh
    # global morphed_image
    # Apply the morphological operation
    morphed_image = cv2.morphologyEx(otsuThresh, cv2.MORPH_OPEN, kernel, iterations=iterations)


    # Display the result
    cv2.imshow('Morphology', morphed_image)




img = cv2.imread('./TC/10.jpg', cv2.IMREAD_GRAYSCALE)
img=ut.resize_with_aspect_ratio(img, height=600)

kernel_size = 2
iterations = 9

# Ensure kernel size is odd and at least 1
kernel_size = max(1, kernel_size * 2 + 1)

morphed_image=img
for i in range(iterations):
    morphed_image = cv2.medianBlur(morphed_image, kernel_size)
    
otsuThresh=cv2.threshold(morphed_image.copy(), 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
ut.showImage(otsuThresh)

# Create a window
cv2.namedWindow('Morphology')

# Create trackbars for operation type, kernel size, and iterations
cv2.createTrackbar('Kernel Size', 'Morphology', 1, 21, apply_morphology)
cv2.createTrackbar('Iterations', 'Morphology', 1, 10, apply_morphology)

# Initial update to display the image
apply_morphology(0)

# Wait until the user exits
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[6], line 5, in apply_morphology(val)
#       2 def apply_morphology(val):
#       3     # Get trackbar positions
#       4     kernel_size = cv2.getTrackbarPos('Kernel Size', 'Morphology')
# ----> 5     iterations = cv2.getTrackbarPos('Iterations', 'Morphology')
#       7     # Ensure kernel size is odd and at least 1
#       8     kernel_size = max(1, kernel_size * 2 + 1)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:866: error: (-215:Assertion failed) trackbar in function 'cv::getTrackbarPos'
