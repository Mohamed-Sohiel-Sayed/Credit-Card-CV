# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import utils as ut
import refFont

font = refFont.Font()

# %%
image = cv2.imread("E:/vs code projects/CreditCardProject/TC/09.jpg")  # Load in grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

blur = cv2.GaussianBlur(gray, (5,5), 0)
canney = cv2.Canny(gray, 100, 200)

angle=ut.isSkewed(gray)
if angle:
    image=ut.fixSkew(image,angle)

ut.showImage(image)
