# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import utils as ut
import refFont

font = refFont.Font()

# %%
imagePaths=ut.getImagePathsInDirectory('./TC')
for i,imagePath in enumerate(imagePaths):
    print(f"TC {i+1}")
    image = cv2.imread("./TC/06.jpg")
    imageCopy=ut.fixPerspective(image.copy(),True)
    ut.showImage(imageCopy)
    break
# Out:
# TC 1
